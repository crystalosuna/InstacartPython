# %% [markdown]
# # Importing

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Folder path 
path = r'/Users/crystalosuna/Documents/05-2023 Instacart Basket Analysis'

# %%
#import orders_products_merged
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_2.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range products
# 1         Soda        77              7     9.0   both  Mid-range products
# 2         Soda        77              7     9.0   both  Mid-range products
# 3         Soda        77              7     9.0   both  Mid-range products
# 4         Soda        77              7     9.0   both  Mid-range products
#
#       busiest_day  Busiest_days Busiest_period_of_day
# 0  Regularly busy  Regular days        Average orders
# 1  Regularly busy  Slowest days        Average orders
# 2  Regularly busy  Slowest days           Most orders
# 3      Least busy  Slowest days        Average orders
# 4      Least busy  Slowest days           Most orders

# %%
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %% [markdown]
# # Step 2

# %%
#aggregate mean of order_number column grouped by department_id
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # Step 3

# %% [markdown]
# The results look more complete and accurate.The mean results for the department_id changed slightly as well compared to having a subset the average being greater in the subset than the entire set.

# %% [markdown]
# # Step 4

# %%
#using transform
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
#
#    product_name  aisle_id  department_id  prices _merge     price_range_loc  \
# 0          Soda        77              7     9.0   both  Mid-range products
# 1          Soda        77              7     9.0   both  Mid-range products
# 2          Soda        77              7     9.0   both  Mid-range products
# 3          Soda        77              7     9.0   both  Mid-range products
# 4          Soda        77              7     9.0   both  Mid-range products
# 5          Soda        77              7     9.0   both  Mid-range products
# 6          Soda        77              7     9.0   both  Mid-range products
# 7          Soda        77              7     9.0   both  Mid-range products
# 8          Soda        77              7     9.0   both  Mid-range products
# 9          Soda        77              7     9.0   both  Mid-range products
# 10         Soda        77              7     9.0   both  Mid-range products
# 11         Soda        77              7     9.0   both  Mid-range products
# 12         Soda        77              7     9.0   both  Mid-range products
# 13         Soda        77              7     9.0   both  Mid-range products
# 14         Soda        77              7     9.0   both  Mid-range products
#
#        busiest_day  Busiest_days Busiest_period_of_day  max_order
# 0   Regularly busy  Regular days        Average orders         10
# 1   Regularly busy  Slowest days        Average orders         10
# 2   Regularly busy  Slowest days           Most orders         10
# 3       Least busy  Slowest days        Average orders         10
# 4       Least busy  Slowest days           Most orders         10
# 5   Regularly busy  Regular days        Average orders         10
# 6   Regularly busy  Busiest days           Most orders         10
# 7   Regularly busy  Busiest days           Most orders         10
# 8   Regularly busy  Busiest days           Most orders         10
# 9       Least busy  Slowest days        Average orders         10
# 10  Regularly busy  Busiest days           Most orders         22
# 11  Regularly busy  Regular days           Most orders         22
# 12  Regularly busy  Regular days           Most orders         22
# 13  Regularly busy  Busiest days           Most orders         22
# 14  Regularly busy  Busiest days           Most orders         22

# %%
#Deriving columns with loc()
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
#checking a random sample
ords_prods_merge[['user_id', 'loyalty_flag', 'max_order']].sample(60)
# Out:
#           user_id      loyalty_flag  max_order
# 2156549    149748  Regular customer         36
# 1946264    182243      New customer          4
# 26200038   126293      New customer          5
# 6286117     44274      New customer          4
# 25299814   204378    Loyal customer         44
# 28105069   122866    Loyal customer         76
# 20839844   160974  Regular customer         11
# 8570832     41384      New customer          5
# 15860620   125903      New customer          3
# 18256450    89533    Loyal customer         67
# 11292557   181337    Loyal customer         43
# 27433828    73477    Loyal customer         70
# 18363105     5101    Loyal customer         99
# 16321774   142894    Loyal customer         64
# 22973584    84454  Regular customer         22
# 18032506    76657  Regular customer         33
# 7939001    204538    Loyal customer         43
# 17166538    96590      New customer          4
# 23230477   203585      New customer          4
# 27983413    15185    Loyal customer         43
# 23066936   177366  Regular customer         22
# 24397240    33235  Regular customer         26
# 29241844    78273      New customer         10
# 4313565     29412  Regular customer         17
# 14515385    93970      New customer          3
# 6349202    153866    Loyal customer         46
# 27182810    16114  Regular customer         16
# 22485460   123619    Loyal customer         46
# 9276345    186673      New customer          5
# 23059187   202796  Regular customer         15
# 7088349    202358  Regular customer         23
# 11960683   186370  Regular customer         25
# 24519328    81603    Loyal customer         57
# 6704059    132438    Loyal customer         77
# 12695150    88054    Loyal customer         99
# 28200421    13996  Regular customer         15
# 7496032     26113  Regular customer         37
# 31374525   114428  Regular customer         19
# 9055388    189753  Regular customer         31
# 15320126   146439  Regular customer         24
# 3561750    117182    Loyal customer         82
# 9269252    162898    Loyal customer         79
# 7155397     23038      New customer          7
# 14122499   149646      New customer          9
# 24899460   178423  Regular customer         32
# 24048643    40018    Loyal customer         47
# 20162309    23705  Regular customer         27
# 15645680    33356  Regular customer         21
# 1016856      4182  Regular customer         18
# 15283800    39320  Regular customer         12
# 8328767    150299  Regular customer         26
# 1795002    115715  Regular customer         16
# 5444568    170821  Regular customer         36
# 30333302   169735  Regular customer         32
# 20360143    47392  Regular customer         32
# 19959119   165292    Loyal customer         58
# 6952486     21597      New customer          8
# 21200588    11261    Loyal customer         57
# 28529112   145222  Regular customer         14
# 26934889   205292      New customer          5

# %% [markdown]
# # Step 5

# %%
print('The mean, min and max of prices grouped by the loyalty_flag column in ords_prods_merge:')
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
# The mean, min and max of prices grouped by the loyalty_flag column in ords_prods_merge:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# I did find it interesting that based on the mean prices the loyal customer has the lower price average and the new customer has a higher price average. This means the products purchased by loyal customers differ from those purchased by regular or new customers.

# %% [markdown]
# # Step 6

# %%
# Creating “average_price” column using transform()
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  department_id  prices  _merge     price_range_loc  \
# 0         Soda  ...              7     9.0    both  Mid-range products
# 1         Soda  ...              7     9.0    both  Mid-range products
# 2         Soda  ...              7     9.0    both  Mid-range products
# 3         Soda  ...              7     9.0    both  Mid-range products
# 4         Soda  ...              7     9.0    both  Mid-range products
#
#       busiest_day  Busiest_days Busiest_period_of_day max_order  loyalty_flag  \
# 0  Regularly busy  Regular days        Average orders        10  New customer
# 1  Regularly busy  Slowest days        Average orders        10  New customer
# 2  Regularly busy  Slowest days           Most orders        10  New customer
# 3      Least busy  Slowest days        Average orders        10  New customer
# 4      Least busy  Slowest days           Most orders        10  New customer
#
#   average_price
# 0      6.367797
# 1      6.367797
# 2      6.367797
# 3      6.367797
# 4      6.367797
#
# [5 rows x 21 columns]

# %%
# Creating a spending_flag flag
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Creating a spending_flag flag
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  prices  _merge     price_range_loc     busiest_day  \
# 0         Soda  ...     9.0    both  Mid-range products  Regularly busy
# 1         Soda  ...     9.0    both  Mid-range products  Regularly busy
# 2         Soda  ...     9.0    both  Mid-range products  Regularly busy
# 3         Soda  ...     9.0    both  Mid-range products      Least busy
# 4         Soda  ...     9.0    both  Mid-range products      Least busy
#
#    Busiest_days Busiest_period_of_day max_order  loyalty_flag  average_price  \
# 0  Regular days        Average orders        10  New customer       6.367797
# 1  Slowest days        Average orders        10  New customer       6.367797
# 2  Slowest days           Most orders        10  New customer       6.367797
# 3  Slowest days        Average orders        10  New customer       6.367797
# 4  Slowest days           Most orders        10  New customer       6.367797
#
#   spending_flag
# 0   Low spender
# 1   Low spender
# 2   Low spender
# 3   Low spender
# 4   Low spender
#
# [5 rows x 22 columns]

# %%
# Check the frequency
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %% [markdown]
# # Step 7

# %%
# Creating “median_prior_orders” column using transform
ords_prods_merge['median_prior_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge     price_range_loc     busiest_day  Busiest_days  \
# 0         Soda  ...    both  Mid-range products  Regularly busy  Regular days
# 1         Soda  ...    both  Mid-range products  Regularly busy  Slowest days
# 2         Soda  ...    both  Mid-range products  Regularly busy  Slowest days
# 3         Soda  ...    both  Mid-range products      Least busy  Slowest days
# 4         Soda  ...    both  Mid-range products      Least busy  Slowest days
#
#   Busiest_period_of_day max_order  loyalty_flag average_price  spending_flag  \
# 0        Average orders        10  New customer      6.367797    Low spender
# 1        Average orders        10  New customer      6.367797    Low spender
# 2           Most orders        10  New customer      6.367797    Low spender
# 3        Average orders        10  New customer      6.367797    Low spender
# 4           Most orders        10  New customer      6.367797    Low spender
#
#   median_prior_orders
# 0                20.5
# 1                20.5
# 2                20.5
# 3                20.5
# 4                20.5
#
# [5 rows x 23 columns]

# %%
# Creating a 'order_frequency_flag' flag
ords_prods_merge.loc[ords_prods_merge['median_prior_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# Creating a 'order_frequency_flag' flag
ords_prods_merge.loc[(ords_prods_merge['median_prior_orders'] > 10) & (ords_prods_merge['median_prior_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# Creating a 'order_frequency_flag' flag
ords_prods_merge.loc[ords_prods_merge['median_prior_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...     price_range_loc     busiest_day  Busiest_days  \
# 0         Soda  ...  Mid-range products  Regularly busy  Regular days
# 1         Soda  ...  Mid-range products  Regularly busy  Slowest days
# 2         Soda  ...  Mid-range products  Regularly busy  Slowest days
# 3         Soda  ...  Mid-range products      Least busy  Slowest days
# 4         Soda  ...  Mid-range products      Least busy  Slowest days
#
#   Busiest_period_of_day max_order  loyalty_flag average_price spending_flag  \
# 0        Average orders        10  New customer      6.367797   Low spender
# 1        Average orders        10  New customer      6.367797   Low spender
# 2           Most orders        10  New customer      6.367797   Low spender
# 3        Average orders        10  New customer      6.367797   Low spender
# 4           Most orders        10  New customer      6.367797   Low spender
#
#    median_prior_orders   order_frequency_flag
# 0                 20.5  Non-frequent customer
# 1                 20.5  Non-frequent customer
# 2                 20.5  Non-frequent customer
# 3                 20.5  Non-frequent customer
# 4                 20.5  Non-frequent customer
#
# [5 rows x 24 columns]

# %%
# Check the frequency
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency_flag, dtype: int64

# %%
#export 
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_updated_2.pkl'))
